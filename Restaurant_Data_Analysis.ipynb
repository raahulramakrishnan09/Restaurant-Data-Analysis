# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('/content/i1.csv')
df2=pd.read_csv('/content/i2.csv')

# %%
#merging_two_data
df=df1.merge(df2,how='outer')
df
# Out:
#              Date            Timestamp  Invoice No.  \
# 0      2023-09-19  2023-09-19 22:03:44        28389
# 1      2023-09-19  2023-09-19 22:03:44        28389
# 2      2023-09-19  2023-09-19 22:03:44        28389
# 3      2023-09-19  2023-09-19 22:03:44        28389
# 4      2023-09-19  2023-09-19 22:03:44        28389
# ...           ...                  ...          ...
# 15616  2023-04-01  2023-04-01 13:16:03        23465
# 15617  2023-04-01  2023-04-01 13:16:03        23465
# 15618  2023-04-01  2023-04-01 13:16:03        23465
# 15619  2023-04-01  2023-04-01 13:16:03        23465
# 15620  2023-04-01  2023-04-01 13:16:03        23465
#
#                          Item Name  Price  Qty.  Sub Total  Discount    Tax  \
# 0                           Kulcha   55.0   1.0       55.0       0.0   2.76
# 1                           Parota   30.0   4.0      120.0       0.0   6.00
# 2                  Mushroom Masala  150.0   1.0      150.0       0.0   7.50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15621 entries, 0 to 15620
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         15621 non-null  object
#  1   Timestamp    15621 non-null  object
#  2   Invoice No.  15621 non-null  int64
#  3   Item Name    15621 non-null  object
#  4   Price        15621 non-null  float64
#  5   Qty.         15621 non-null  float64
#  6   Sub Total    15621 non-null  float64
#  7   Discount     15621 non-null  float64
#  8   Tax          15621 non-null  float64
#  9   Final Total  15621 non-null  float64
#  10  Table No.    15613 non-null  float64
#  11  Server Name  15621 non-null  object
#  12  Covers       15621 non-null  int64
#  13  Variation    15 non-null     object
#  14  Category     15621 non-null  object
#  15  HSN          0 non-null      float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 1.9+ MB

# %%
df.head()
# Out:
#          Date            Timestamp  Invoice No.             Item Name  Price  \
# 0  2023-09-19  2023-09-19 22:03:44        28389                Kulcha   55.0
# 1  2023-09-19  2023-09-19 22:03:44        28389                Parota   30.0
# 2  2023-09-19  2023-09-19 22:03:44        28389       Mushroom Masala  150.0
# 3  2023-09-19  2023-09-19 22:03:44        28389  Paneer Butter Masala  150.0
# 4  2023-09-19  2023-09-19 22:03:44        28389              Gobi- 65  120.0
#
#    Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0   1.0       55.0       0.0  2.76        57.76       16.0      biller
# 1   4.0      120.0       0.0  6.00       126.00       16.0      biller
# 2   1.0      150.0       0.0  7.50       157.50       16.0      biller
# 3   1.0      150.0       0.0  7.50       157.50       16.0      biller
# 4   1.0      120.0       0.0  6.00       126.00       16.0      biller
#
#    Covers Variation       Category  HSN
# ...

# %%
df.tail()
# Out:
#              Date            Timestamp  Invoice No.  \
# 15616  2023-04-01  2023-04-01 13:16:03        23465
# 15617  2023-04-01  2023-04-01 13:16:03        23465
# 15618  2023-04-01  2023-04-01 13:16:03        23465
# 15619  2023-04-01  2023-04-01 13:16:03        23465
# 15620  2023-04-01  2023-04-01 13:16:03        23465
#
#                          Item Name  Price  Qty.  Sub Total  Discount   Tax  \
# 15616         Paneer Butter Masala  150.0   2.0      300.0       0.0  15.0
# 15617  Schewan  Chicken Fried Rice  160.0   1.0      160.0       0.0   8.0
# 15618      Schezwan Egg Fried Rice  140.0   1.0      140.0       0.0   7.0
# 15619            Chicken Kati Roll  120.0   1.0      120.0       0.0   6.0
# 15620             Soft Drink 600ml   40.0   2.0       80.0       0.0   4.0
#
#        Final Total  Table No. Server Name  Covers Variation  \
# 15616        315.0       20.0      biller       0       NaN
# 15617        168.0       20.0      biller       0       NaN
# ...

# %%
df.describe()
# Out:
#         Invoice No.         Price          Qty.     Sub Total      Discount  \
# count  15621.000000  15621.000000  15621.000000  15621.000000  15621.000000
# mean   25989.963127    116.608988      1.338839    147.407080      1.262818
# std     1433.192998     63.663769      0.949814    210.127442      6.656396
# min    23465.000000     12.000000      1.000000     12.000000      0.000000
# 25%    24751.000000     50.000000      1.000000     80.000000      0.000000
# 50%    25980.000000    140.000000      1.000000    150.000000      0.000000
# 75%    27274.000000    160.000000      1.000000    170.000000      0.000000
# max    28389.000000    770.000000     28.000000  21560.000000    288.000000
#
#                 Tax   Final Total     Table No.   Covers  HSN
# count  15621.000000  15621.000000  15613.000000  15621.0  0.0
# mean       7.303668    153.447930     18.068340      0.0  NaN
# std       10.461474    219.678163     17.191377      0.0  NaN
# ...

# %%
df.shape
# Out:
# (15621, 16)

# %%
a=df['Price']
b=df['Discount']
c=df['Qty.']

# %%
#line_plot
plt.plot(a)

# %%
#scatter_plot
plt.scatter(a,b)

# %%
#bar_plot
plt.bar(a,height=30,width=20)
# Out:
# <BarContainer object of 15621 artists>

# %%
#histogtram
plt.hist(a)
# Out:
# (array([5.476e+03, 6.989e+03, 3.028e+03, 1.100e+01, 5.900e+01, 5.700e+01,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 12. ,  87.8, 163.6, 239.4, 315.2, 391. , 466.8, 542.6, 618.4,
#         694.2, 770. ]),
#  <BarContainer object of 10 artists>)

# %%
#lineplot_using_seaborn
sns.lineplot(x=a,y=b,data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Discount'>

# %%
#scatterplot_using_seaborn
sns.scatterplot(x=a,y=b,data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Discount'>

# %%
#barplot_using_seaborn
sns.barplot(x=b,y=c,data=df)
# Out:
# <Axes: xlabel='Discount', ylabel='Qty.'>

# %%
#distribution_plot_using_seaborn
sns.distplot(c)
# Out:
# <ipython-input-400-645075847f75>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(c)
# <Axes: xlabel='Qty.', ylabel='Density'>

# %%
#pairplot_using_seaborn
sns.pairplot(data=df,hue='Final Total')

# %%
#counterplot_using_seaborn
sns.countplot(x=c,data=df)
# Out:
# <Axes: xlabel='Qty.', ylabel='count'>

# %%
#Finding_missing_values
import missingno as msno
msno.bar(df)
plt.show()

# %%
#Dropping_the_table_with_more_missing_values
df=df.drop(['Date','HSN','Timestamp','Covers','Table No.','Server Name','Variation'],axis=1)

# %%
#Total_orders
avg1=df['Invoice No.'].nunique()

# %%
#Total_amount
avg2=df['Final Total'].sum()

# %%
#Average_order_value
avg=avg2/avg1
avg
# Out:
# 486.70256243654825

# %%
#Using_Groupby
new_df=df.groupby('Invoice No.').agg({'Invoice No.': lambda x:x.nunique(),'Qty.': lambda x:x.sum(),
                                      'Final Total': lambda x:x.sum(),'Item Name': lambda x:x.sum(),})
new_df.columns=['INVOICE_NO','QUANTITY','AMOUNT','ITEM_NAME']
new_df
# Out:
#              INVOICE_NO  QUANTITY   AMOUNT  \
# Invoice No.
# 23465                 1      11.0  1134.00
# 23466                 1       5.0   441.00
# 23467                 1       5.0   774.88
# 23468                 1       2.0   273.00
# 23469                 1       5.0   462.00
# ...                 ...       ...      ...
# 28385                 1       6.0   493.50
# 28386                 1      14.0  1479.44
# 28387                 1       9.0  1501.50
# 28388                 1      11.0  1928.82
# 28389                 1      10.0   666.76
#
#                                                      ITEM_NAME
# Invoice No.
# 23465        Babycorn ManchurianPulka (2 No)Paneer Butter M...
# 23466        Chocolate Milk ShakeChocolate Milk ShakeSchezw...
# 23467        Chicken Biriyani With Raitha And GravyPrawn Pe...
# 23468                        Plain Briyani With Raitha, Gravy.
# 23469        Chicken Biriyani With Raitha And GravyEgg Frie...
# ...

# %%
#visualizing the top_10 Items using barplot
top_10_descriptions=df['Item Name'].value_counts().nlargest(10)
sns.barplot(x=top_10_descriptions.values,y=top_10_descriptions.index)
plt.xlabel('Count')
plt.ylabel('Items')
plt.title('Top 10 Items Descriptions')
plt.show()

# %%
#visualizing the top_10 categories using barplot
top_10_descriptions=df['Category'].value_counts().nlargest(10)
sns.barplot(x=top_10_descriptions.values,y=top_10_descriptions.index)
plt.xlabel('Count')
plt.ylabel('categories')
plt.title('Top 10 Category Descriptions')
plt.show()

# %%
#visualizing the top_10 Items based on Quantity
top_10=df.groupby('Item Name')['Qty.'].sum().nlargest(10)
sns.barplot(x=top_10.values,y=top_10.index)
plt.xlabel('Quantity')
plt.ylabel('Items')
plt.title('Top 10 Items based on Quantity')
plt.xticks(rotation=45)
plt.show()

# %%
#visualizing the top_10 Items based on Final Total
top_10=df.groupby('Item Name')['Final Total'].sum().nlargest(10)
sns.barplot(x=top_10.values,y=top_10.index)
plt.xlabel('Amount')
plt.ylabel('Items')
plt.title('Items based on Final Total')
plt.show()

# %%
#visualizing the top_05 Category based on Discount
top_10=df.groupby('Category')['Discount'].mean().nlargest(5)
sns.barplot(x=top_10.values,y=top_10.index)
plt.xlabel('Total Discount')
plt.ylabel('Category based on Discount')
plt.title('Items')
plt.show()

# %%
#visualizing the top_05 Category based on Quantity
top_10=df.groupby('Category')['Qty.'].sum().nlargest(5)
sns.barplot(x=top_10.values,y=top_10.index)
plt.xlabel('Quantity')
plt.ylabel('Category')
plt.title('Category based on Quantity')
plt.show()

# %%
#visualizing the top_05 Category based on Final Total
top_10=df.groupby('Category')['Final Total'].sum().nlargest(5)
sns.barplot(x=top_10.values,y=top_10.index)
plt.xlabel('Amount')
plt.ylabel('Category')
plt.title("Category based on Final Total")
plt.show()

# %%
#visualizing the top_10 Invoice No. and Items together based on Quantity
top_10=df.groupby(['Invoice No.','Item Name'])['Qty.'].sum().nlargest(10)
top_10.plot(kind='bar',color='skyblue')
# Out:
# <Axes: xlabel='Invoice No.,Item Name'>

# %%
#Number_of_Fish_65_Ordered
k=df[df['Item Name']=='Fish 65']
print("Number of Fish_65 Ordered:",k['Qty.'].sum())
# Out:
# Number of Fish_65 Ordered: 109.0

# %%
#Number_of_Customers_Ordered_Parota
p=df[df['Item Name']=='Parota']
p1=p.groupby('Item Name').agg({'Invoice No.': lambda x:x.nunique()})
p1.columns=['NO_OF_CUSTOMERS_ORDERED']
p1
# Out:
#            NO_OF_CUSTOMERS_ORDERED
# Item Name
# Parota                          20

# %%
#Quantity_of_Blue_Lagoon
m=df[df['Item Name']=='Blue Lagoon']
m1=m.groupby('Item Name').agg({'Qty.':lambda x:x.sum()})
m1.columns=['NUMBER_OF_ITEMS_ORDERED']
m1
# Out:
#              NUMBER_OF_ITEMS_ORDERED
# Item Name
# Blue Lagoon                    191.0

# %%
#Number_of_Customers_Ordered_and_Quantity_of_Romali_Roti(1 No)
n=df[df['Item Name']=='Romali Roti (1 No)']
n1=n.groupby('Item Name').agg({'Qty.':lambda x:x.sum(),
                               'Invoice No.': lambda x:x.nunique()})
n1.columns=['NUMBER_OF_ITEMS_ORDERED','NO_OF_CUSTOMERS_ORDERED']
n1
# Out:
#                     NUMBER_OF_ITEMS_ORDERED  NO_OF_CUSTOMERS_ORDERED
# Item Name
# Romali Roti (1 No)                    822.0                      318

# %%
#Number_of_Invoices_with_charged_tax_of_14
o=df[df['Tax']==14]
o1=o.groupby('Tax').agg({'Invoice No.':lambda x:x.nunique()})
o1.columns=['NO_OF_CUSTOMERS_ORDERED']
o1
# Out:
#       NO_OF_CUSTOMERS_ORDERED
# Tax
# 14.0                       72

# %%
#Number_of_'Plain Briyani With Raitha, Gravy.'_ordered_with_Discount_of_6.5
q=df[(df['Item Name']=='Plain Briyani With Raitha, Gravy.') & (df['Discount']==6.5)]
print("Number of 'Plain Briyani With Raitha, Gravy.' ordered with Discount of 6.5:",q['Invoice No.'].nunique())
# Out:
# Number of 'Plain Briyani With Raitha, Gravy.'_ordered_with Discount of 6.5: 1
